# %% [markdown]
# ## Write the following expressions in Tex-notation.

# %% [markdown]
# ## Mark 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Write your solutions below

# %% [markdown]
# $a^2$

# %% [markdown]
# ${(a^2b)}^3$

# %% [markdown]
# $2x^2 + 1 = x - (2x + 1)^2$

# %% [markdown]
# $\frac{1}{x + 2}$

# %% [markdown]
# ## Mark 2
#
# The third one with three equations must be enclosed within `$$ ... $$`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Write your solutions below

# %% [markdown]
# ${(a + b)}^{m+n}$

# %% [markdown]
# $\frac{1}{1+\sqrt{x+1}}$

# %% [markdown]
# $$\begin{align}2x + 1 = 1 -2x \\ x = x^2 -1 \\ (2x +1)^2 = 1  \end{align}$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Write your solutions below

# %% [markdown]
# $$
# \frac{4}{\pi}
# = 1 + \cfrac{1^2}{2 + \cfrac{3^2}{2 + \cfrac{5^2}{2 + \ddots}}}.
# $$

# %% [markdown]
# $$

# %% [markdown]
# $$
# \nabla \bigl(x_1^2 + x_1 x_2^2 - x_2 x_1\bigr)
# = \begin{pmatrix}
# 2x_1 + x_2^2 - x_2 \\
# 2x_1 x_2 - x_1
# \end{pmatrix}.
# $$
